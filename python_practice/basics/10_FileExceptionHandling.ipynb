# %% [markdown]
# ```text
# Exception handling in Python manages runtime errors gracefully, preventing programs from crashing unexpectedly.
# ```

# %% [markdown]
# ```text
# Python uses try, except, else, and finally blocks to handle exceptions:
# ```
