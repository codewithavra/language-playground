# %% [markdown]
# ## Q. Take input of two integers and print their sum
# input :
# 2
# 3
# output :
# sum 5

# %%
a = int(input('Enter the first number : '))
b = int(input('Enter the second number : '))
print('sum',a+b)
# Out:
# sum 5

# %%
num = int(input())
den = int(input())

if den == 0 :
    print("Divison not possible")
else:
    print("quotient", num//den)
# Out:
# Divison 2

# %%
print(95/2) # Float division
print(95//2) # Floor division
print(10 % 3) # Remainder
# Out:
# 47.5
# 47
# 1

# %%
s = "Python"
   # 012345
print(s[:4])
# Out:
# Pyth

# %%
s= "Hello"
print(s[::-1])
# Out:
# olleH
